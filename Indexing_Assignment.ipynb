# %% [markdown]
# <a href="https://colab.research.google.com/github/mamudurujagadeesh7-cloud/Edukron-DS/blob/main/Indexing_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
text = "Edukron data science and data engineering batch 2026"

# %% [markdown]
# 1.indexing expression to print "data"

# %%
print(text[8:12])
# Out:
# data

# %%
print(text[-44:-40])
# Out:
# data

# %% [markdown]
# 2.indexing expression to print "Edukron"

# %%
print(text[0:7])
# Out:
# Edukron

# %%
print(text[-52:-45])
# Out:
# Edukron

# %% [markdown]
# 3.indexing expression to print"science"

# %%
print(text[13:20])
# Out:
# science

# %%
print(text[-39:-32])
# Out:
# science

# %% [markdown]
# 4.indexing expression to print "and"

# %%
print(text[21:24])
# Out:
# and

# %%
print(text[-31:-28])
# Out:
# and

# %% [markdown]
# 5.indexing expression to print "data engineering"

# %%
print(text[24:41])
# Out:
#  data engineering

# %%
print(text[-27:-11])
# Out:
# data engineering

# %% [markdown]
# 6.indexing expression to print "engineering"

# %%
print(text[30:41])
# Out:
# engineering

# %%
print(text[-22:-11])
# Out:
# engineering

# %% [markdown]
# 7.indexing expression to print "batch"

# %%
print(text[42:47])
# Out:
# batch

# %%
print(text[-10:-5])
# Out:
# batch

# %% [markdown]
# 8.indexing expression to print "2026"

# %%
print(text[48:52])
# Out:
# 2026

# %%
print(text[-4:])
# Out:
# 2026

# %% [markdown]
# 9.indexing expression to print "science and data"

# %%
print(text[13:29])
# Out:
# science and data

# %%
print(text[-39:-23])
# Out:
# science and data

# %% [markdown]
# 10.indexing expression to print "data science and data engineering"

# %%
print(text[8:41])
# Out:
# data science and data engineering

# %%
print(text[-44:-5])
# Out:
# data science and data engineering batch

# %% [markdown]
# Q0: Print length of Edukron batch text
#
# Q5: Positive slice text[25:42]
#
# Q6: Positive slice text[30:42]
#
# Q7: Positive slice text[42:48]
#
# Q10: Positive slice text[8:48]

# %%
print(len(text))
# Out:
# 52

# %%
print(text[25:42])
# Out:
# data engineering

# %%
print(text[30:42])
# Out:
# engineering

# %%
print(text[42:48])
# Out:
# batch

# %%
print(text[8:48])
# Out:
# data science and data engineering batch

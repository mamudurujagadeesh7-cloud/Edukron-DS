# %% [markdown]
# <a href="https://colab.research.google.com/github/mamudurujagadeesh7-cloud/Edukron-DS/blob/main/Assignment%202.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
bank = [ [ [["C101", "Rahul", "Savings", 85000],
            ["C102", "Anita", "Current", 150000],
            ["C103", "Kiran", "Loan", 500000] ],

          [["C104", "Sneha", "Savings", 95000],
           ["C105", "Vikram", "Current", 275000],
           ["C106", "Meena", "Loan", 750000] ] ],

[
    [
        ["C201", "Arjun", "Savings", 120000],
        ["C202", "Pooja", "Current", 325000],
        ["C203", "Ramesh", "Loan", 900000]
    ],
    [
        ["C204", "Priya", "Savings", 45000],
        ["C205", "Amit", "Current", 185000],
        ["C206", "Divya", "Loan", 650000]
    ]
],

[
    [
        ["C301", "Nikhil", "Savings", 78000],
        ["C302", "Kavya", "Current", 240000],
        ["C303", "Suresh", "Loan", 1000000]
    ],
    [
        ["C304", "Neha", "Savings", 135000],
        ["C305", "Rohan", "Current", 410000],
        ["C306", "Asha", "Loan", 550000]
    ]
]
]

# %%
print(bank[0][0][0])
# Out:
# ['C101', 'Rahul', 'Savings', 85000]

# %%
print(bank[0][0][1][2])
# Out:
# Current

# %%
print(bank[0][0][2][3])
# Out:
# 500000

# %%
print(bank[0][1][0][0])
# Out:
# C104

# %%
print(bank[0][1][1][3])
# Out:
# 275000

# %%
print(bank[0][1][2])
# Out:
# ['C106', 'Meena', 'Loan', 750000]

# %%
print(bank[1][0][0][0])
# Out:
# C201

# %%
print(bank[1][0][1][1])
# Out:
# Pooja

# %%
print(bank[1][0][2][2])
# Out:
# Loan

# %%
print(bank[1][1][0][3])
# Out:
# 45000

# %%
print(bank[1][1][1][2])
# Out:
# Current

# %%
print(bank[1][1][2][0])
# Out:
# C206

# %%
print(bank[2][0][0][2])
# Out:
# Savings

# %%
print(bank[2][0][1][3])
# Out:
# 240000

# %%
print(bank[2][0][2][3])
# Out:
# 1000000

# %%
print(bank[2][1][0][1])
# Out:
# Neha

# %%
print(bank[2][1][1])
# Out:
# ['C305', 'Rohan', 'Current', 410000]

# %%
print(bank[2][1][2][2])
# Out:
# Loan

# %%
print(bank[0][0])
# Out:
# [['C101', 'Rahul', 'Savings', 85000], ['C102', 'Anita', 'Current', 150000], ['C103', 'Kiran', 'Loan', 500000]]

# %%
print(bank[0][1])
# Out:
# [['C104', 'Sneha', 'Savings', 95000], ['C105', 'Vikram', 'Current', 275000], ['C106', 'Meena', 'Loan', 750000]]

# %%
print(bank[1][0])
# Out:
# [['C201', 'Arjun', 'Savings', 120000], ['C202', 'Pooja', 'Current', 325000], ['C203', 'Ramesh', 'Loan', 900000]]

# %%
print(bank[1][1])
# Out:
# [['C204', 'Priya', 'Savings', 45000], ['C205', 'Amit', 'Current', 185000], ['C206', 'Divya', 'Loan', 650000]]

# %%
print(bank[2][0])
# Out:
# [['C301', 'Nikhil', 'Savings', 78000], ['C302', 'Kavya', 'Current', 240000], ['C303', 'Suresh', 'Loan', 1000000]]

# %%
print(bank[2][1])
# Out:
# [['C304', 'Neha', 'Savings', 135000], ['C305', 'Rohan', 'Current', 410000], ['C306', 'Asha', 'Loan', 550000]]

# %%
print(bank[0])
# Out:
# [[['C101', 'Rahul', 'Savings', 85000], ['C102', 'Anita', 'Current', 150000], ['C103', 'Kiran', 'Loan', 500000]], [['C104', 'Sneha', 'Savings', 95000], ['C105', 'Vikram', 'Current', 275000], ['C106', 'Meena', 'Loan', 750000]]]

# %%
print(bank[1])
# Out:
# [[['C201', 'Arjun', 'Savings', 120000], ['C202', 'Pooja', 'Current', 325000], ['C203', 'Ramesh', 'Loan', 900000]], [['C204', 'Priya', 'Savings', 45000], ['C205', 'Amit', 'Current', 185000], ['C206', 'Divya', 'Loan', 650000]]]

# %%
print(bank[2])
# Out:
# [[['C301', 'Nikhil', 'Savings', 78000], ['C302', 'Kavya', 'Current', 240000], ['C303', 'Suresh', 'Loan', 1000000]], [['C304', 'Neha', 'Savings', 135000], ['C305', 'Rohan', 'Current', 410000], ['C306', 'Asha', 'Loan', 550000]]]

# %%
print(bank[0][0][0][1])
print(bank[1][0][0][1])
print(bank[2][0][0][1])
# Out:
# Rahul
# Arjun
# Nikhil

# %%
print(bank[0][1][1][1])
print(bank[1][1][1][1])
print(bank[2][1][1][1])
# Out:
# Vikram
# Amit
# Rohan

# %%
bank[2][1][-1][-1]
# Out:
# 550000

# %% [markdown]
# 1. Create a list of 5 employee names and add a new employee using append().

# %%
employee = ["Rahul",  "Kiran", "Sneha"]
employee.append('DS')
print(employee)
# Out:
# ['Rahul', 'Kiran', 'Sneha', 'DS']

# %% [markdown]
# 2. Create a list of account numbers and add three new account numbers using extend().

# %%
Account = [ 120000, 45000, 275000]
Account.extend([10000,94000,67800])
Account
# Out:
# [120000, 45000, 275000, 10000, 94000, 67800]

# %% [markdown]
# 3. Insert a new customer at the beginning of a customer list using insert().

# %%
customer = ["A", "B", "C", "D"]
customer.insert(0, "J")
print(customer)
# Out:
# ['J', 'A', 'B', 'C', 'D']

# %% [markdown]
# 4. Insert a transaction amount at index 3 in a list.

# %%
transaction = [10000, 50000, 20000, 40000]
transaction.insert(3, 30000)
print(transaction)
# Out:
# [10000, 50000, 20000, 30000, 40000]

# %% [markdown]
# 5. Remove the last item from a list using pop().

# %%
item = ['a','b','c','d']
item.pop(-1)
item
# Out:
# ['a', 'b', 'c']

# %% [markdown]
# 6. Remove the customer "Rahul" from a customer list using remove().

# %%
customers = {"Rahul","Sneha","Vikram"}
customers.remove("Rahul")
customers
# Out:
# {'Sneha', 'Vikram'}

# %% [markdown]
# 7. Count how many times the account type "Savings" appears in a list using `count()`.

# %%
acc_types = ["Savings", "Current","Savings", "Loan"]
acc_types.count("Savings")
# Out:
# 2

# %% [markdown]
# 8. Find the index of "Current" in a list of account types using `index()`.

# %%
acc_types = ["Savings","Current","Loan"]
acc_types.index("Current" )
# Out:
# 1

# %% [markdown]
# 9. Reverse a list of transaction IDs using `reverse()`.

# %%
transaction_ids = [1,2,3,4,5]
transaction_ids.reverse()
transaction_ids
# Out:
# [5, 4, 3, 2, 1]

# %% [markdown]
# 10. Sort a list of account balances in ascending order using `sort()`.

# %%
balances = [ 95000, 26000, 27800]
balances.sort()
balances
# Out:
# [26000, 27800, 95000]

# %% [markdown]
# 11. Sort a list of customer names in descending order using `sort()`.

# %%
customers = ["Kiran", "Sneha", "Vikram"]
customers.sort(reverse=True)
customers
# Out:
# ['Vikram', 'Sneha', 'Kiran']

# %% [markdown]
# 12. Make a copy of a list using `copy()` and verify that modifying the copied list does not affect the original list.

# %%
customers = ["Rahul", "Anita", "Kiran", "Sneha", "Vikram"]
copycust=customers.copy()
copycust[2]="gandhi"
print(copycust)
print(customers)
# Out:
# ['Rahul', 'Anita', 'gandhi', 'Sneha', 'Vikram']
# ['Rahul', 'Anita', 'Kiran', 'Sneha', 'Vikram']

# %% [markdown]
# 13. Clear all elements from a list using `clear()`.

# %%
cus = ["rahul", "manoj", "kiran"]
cus.clear()
print(cus)
# Out:
# []

# %% [markdown]
# 14. Append a nested list containing a new customer's details to an existing customer list.

# %%
customer =  [["C101", "Rahul", "Savings", 85000],["C102", "Anita", "Current", 150000]]
new_customer = ["D101", "Teja", "Savings", 35000]
customer.append(new_customer)
customer
# Out:
# [['C101', 'Rahul', 'Savings', 85000],
#  ['C102', 'Anita', 'Current', 150000],
#  ['D101', 'Teja', 'Savings', 35000]]

# %% [markdown]
# 15. Extend a list of branch names with another list of new branches.

# %%
branche = ['a','b','c']
new_branch = ['d','e','f']
branche.extend(new_branch)
branche
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f']

# %% [markdown]
# 16. Remove the first occurrence of the balance `50000` from a list using `remove()`.

# %%
balances = [10000,20000,50000,60000,50000]
balances.remove(50000)
balances
# Out:
# [10000, 20000, 60000, 50000]

# %% [markdown]
# 17. Pop the element at index 2 from a list and print the removed value.

# %%
bank_branches = ["BTM","Electronic City","Whitefield"]
R=bank_branches.pop(2)
R
# Out:
# 'Whitefield'

# %% [markdown]
# 18. Count how many times the city "Bangalore" appears in a list.

# %%
cities = ["Hyderabad","Bangalore", "Chennai","Bangalore"]
cities.count("Bangalore")
# Out:
# 2

# %% [markdown]
# 19. Reverse a list of bank names and print the result.

# %%
bank_branches_names = ["BTM","Electronic City","Whitefield"]
bank_branches_names.reverse()
bank_branches_names
# Out:
# ['Whitefield', 'Electronic City', 'BTM']

# %% [markdown]
# 20. Create a list of loan amounts and sort it in descending order.

# %%
loan_amount = [10,20,50,30]
loan_amount.sort(reverse=True)
loan_amount
# Out:
# [50, 30, 20, 10]
